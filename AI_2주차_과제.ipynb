# %%
#LAB 2-1
print('나의 이름은 :','이다연')
print('나의 나이는 :',22)
print('나의 키는',164, 'cm입니다.')
print('10 + 20=', 10+20)
print('10 * 20 =', 10 * 20)
# Out:
# 나의 이름은 : 이다연
# 나의 나이는 : 22
# 나의 키는 164 cm입니다.
# 10 + 20= 30
# 10 * 20 = 200

# %%
#LAB 2-4
name = '전우치'
print('나의 이름은 :', name)
age = 27
print('나의 나이는 :', age)
height = 179
print('나의 키는', height, 'cm입니다.')
sum = 10 + 20
print('10 + 20 =',sum)
mult = 10 * 20
print('10 * 20 =',mult)
# Out:
# 나의 이름은 : 전우치
# 나의 나이는 : 27
# 나의 키는 179 cm입니다.
# 10 + 20 = 30
# 10 * 20 = 200

# %%
#LAB 2-6
width = 20
height = 40
width = 30
area = width * height
print('사각형의 면적', area)
# Out:
# 사각형의 면적 1200

# %%
# LAB 2-7 1번
print(123 * 456)
print(1357 + 2468)
print(5 ** 4)
print(10 / 4)
print(10 // 5)
print(10 % 5)
# Out:
# 0

# %%
#LAB 2-7 2번
5 % 2
# Out:
# 1

# %%
# LAB 2-7 3번
print(2 ** 0.5)
print(3 ** 0.5)
# Out:
# 1.7320508075688772

# %%
# LAB 2-8
a = 8 + 2j
b = 4 + 3j

print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# (12+5j)
# (4-1j)
# (26+32j)
# (1.52-0.64j)

# %%
#LAB 2-9
a = 1024

print(a >> 1)
print(a >> 2)

a = a >> 1
print(a)

a = a >> 1
print(a)


a = 1

print(a << 1)

a = a << 1
print(a)

a = a << 1
print(a)

a = a << 1
print(a)

a = a << 1
print(a)
# Out:
# 512
# 256
# 512
# 256
# 2
# 2
# 4
# 8
# 16

# %%
#LAB 2-10 1번
name = input('이름을 입력하세요 : ')
print(name, '님이 입장하셨습니다.')
# Out:
# 이름을 입력하세요 : 김유신
# 김유신 님이 입장하셨습니다.

# %%
#LAB 2-10 2번
m = int(input('숫자 m을 입력하세요 : '))
n = int(input('숫자 n을 입력하세요 : '))
print("m + n =", m + n)
print("m - n =", m - n)
# Out:
# 숫자 m을 입력하세요 : 30
# 숫자 n을 입력하세요 : 50
# m + n = 80
# m - n = -20

# %%
#LAB 2-10 3번
r = int(input("반지름을 입력하세요 : "))
area = 3.14 * r * r
print("원의 면적 =", area)
# Out:
# 반지름을 입력하세요 : 5
# 원의 면적 = 78.5
